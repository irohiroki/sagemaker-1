# %%
# %cd ray-docker
# Out:
# /home/ec2-user/SageMaker/sagemaker-1/ray-docker

# %%
! aws ecr get-login-password --region ap-northeast-1 | docker login --username AWS --password-stdin 462105765813.dkr.ecr.ap-northeast-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !aws ecr describe-images --region ap-northeast-1 --registry-id 462105765813 --repository-name sagemaker-rl-ray-container
# Out:
# An error occurred (AccessDeniedException) when calling the DescribeImages operation: User: arn:aws:sts::401753367667:assumed-role/AmazonSageMaker-ExecutionRole-20241120T161408/SageMaker is not authorized to perform: ecr:DescribeImages on resource: arn:aws:ecr:ap-northeast-1:462105765813:repository/sagemaker-rl-ray-container because no resource-based policy allows the ecr:DescribeImages action

# %%
# !docker logout 462105765813.dkr.ecr.ap-northeast-1.amazonaws.com
# Out:
# Removing login credentials for 462105765813.dkr.ecr.ap-northeast-1.amazonaws.com

# %%
# !aws ecr get-login-password --region ap-southeast-1 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.ap-southeast-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !aws ecr describe-images --region ap-southeast-1 --registry-id 763104351884 --repository-name autogluon-training
# Out:
# {
#     "imageDetails": [
#         {
#             "registryId": "763104351884",
#             "repositoryName": "autogluon-training",
#             "imageDigest": "sha256:34a52fd050f20a3816485f77959cef6eb79256852dccd8ca537eb2f55a334577",
#             "imageTags": [
#                 "1.1.0-cpu-py310-ubuntu20.04-v1.0-2024-05-13-23-57-04",
#                 "1.1.0-cpu-py310-ubuntu20.04-v1.0"
#             ],
#             "imageSizeInBytes": 2420497570,
#             "imagePushedAt": 1715648781.0,
#             "imageManifestMediaType": "application/vnd.docker.distribution.manifest.v2+json",
#             "artifactMediaType": "application/vnd.docker.container.image.v1+json",
#             "lastRecordedPullTime": 1715648787.271
#         },
#         {
#             "registryId": "763104351884",
#             "repositoryName": "autogluon-training",
#             "imageDigest": "sha256:8643c372eca215734e06d7b18940386bfe8e003075be4a0a32010d7eb676f0f5",
#             "imageTags": [
# ...

# %%
# !docker logout 462105765813.dkr.ecr.ap-southeast-1.amazonaws.com
# Out:
# Removing login credentials for 462105765813.dkr.ecr.ap-southeast-1.amazonaws.com

# %%
# !aws ecr get-login-password --region ap-northeast-1 | docker login --username AWS --password-stdin 462105765813.dkr.ecr.ap-northeast-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
image_uris.retrieve(framework='ray-pytorch',region='ap-northeast-1',version='1.6.0',instance_type='ml.t3.medium')
# Out:
# [01/25/25 04:48:34] INFO     Defaulting to only available Python version: py36                    ]8;id=265079;file:///home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=775655;file:///home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/image_uris.py#608\608]8;;\
# '462105765813.dkr.ecr.ap-northeast-1.amazonaws.com/sagemaker-rl-ray-container:ray-1.6.0-torch-cpu-py36'

# %%
# !docker build -t ray-cartpole-dev .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.1s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 289B                                       0.0s
#  => ERROR [internal] load metadata for 462105765813.dkr.ecr.ap-northeast-  0.1s
#  => [auth] sharing credentials for 462105765813.dkr.ecr.ap-northeast-1.am  0.0s
# [+] Building 0.2s (3/3) FINISHED                                 docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 289B                                       0.0s
#  => ERROR [internal] load metadata for 462105765813.dkr.ecr.ap-northeast-  0.1s
#  => [auth] sharing credentials for 462105765813.dkr.ecr.ap-northeast-1.am  0.0s
# ------
# ...
